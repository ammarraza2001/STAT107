# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - Refer to your **lecture notebook** and the **pandas cheat sheet** to help you out with the code!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = ""
ca1_name = ""
ca2_name = ""


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = ""
partner1_netid = ""
partner1_inYourGroupLastWeek = "yes"

partner2_name = ""
partner2_netid = ""
partner1_inYourGroupLastWeek = "yes"

partner3_name = ""
partner3_netid = ""
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the "Hello Dataset".  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *Do you have any pets?*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa22.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`:

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa22.csv")
df
# Out:
#              Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0          CA Ana  AL1                    2.0                    5.0
# 1          CA Ram  AYR                    2.0                    5.0
# 2          CA Xin  AYO                    1.0                    5.0
# 3           Lekha  AYH                    2.0                    2.0
# 4            Reni  AYD                    2.0                    5.0
# ..            ...  ...                    ...                    ...
# 519          Bill  AYC                    1.0                    5.0
# 520       Renault  AYR                    2.0                    5.0
# 521  Shivam Patel  AYC                    1.0                    3.0
# 522         Colin  AYI                    1.0                    5.0
# 523          Evan  AYG                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 1                                            2-Jan                 7UP
# 2                                            2-Jan         Sierra Mist
# 3                                              0.5                 7UP
# 4                                            2-Jan                 7UP
# ..                                             ...                 ...
# 519                                          2-Jan         Sierra Mist
# 520                                            0.5         Sierra Mist
# 521                                            0.5                 7UP
# 522                                          2-Jan         Sierra Mist
# 523                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 1               iOS            Apple           NaN     On/After July 1  ...
# 2               iOS            Apple          Beef   On/Before June 30  ...
# 3               iOS           Orange          Pork     On/After July 1  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
# 520         Android           Orange          Pork   On/Before June 30  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 522             iOS           Orange          Beef   On/Before June 30  ...
# 523         Android           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 1                               Black coffee
# 2                                  starbucks
# 3                        pumpkin spice latte
# 4                                      Mocha
# ..                                       ...
# 519                                      NaN
# 520                                     moca
# 521                          Don’t have one
# 522                                      tea
# 523                                      Tea
#
#     What is your favorite mobile app?  What is your favorite subject?  \
# 0                            Snapchat                            Math
# 1                      Google chrome                      Mathematics
# 2                           Starbucks                      Psychology
# 3                             twitter               english (writing)
# 4                           Instagram                            Math
# ..                                ...                             ...
# 519                               NaN                             NaN
# 520                           wechat                              cs
# 521                           Youtube                  World History
# 522                           YouTube                            Math
# 523                          Facebook  Probability and Measure Theory
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 1                          TWICE                        Spring
# 2                  Five Exercuse                        Winter
# 3                   lana del rey                        autumn
# 4                  Mark kozelek                         Winter
# ..                           ...                           ...
# 519                          NaN                           NaN
# 520              Michael Jackson                        Spring
# 521                   Kumar Sanu                        Summer
# 522                   The Weeknd                        Summer
# 523               Fredie Mercury                        Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 1                     Scorpio      Player Unkown's Battleground
# 2                    aquarius                              None
# 3                         leo                   animal crossing
# 4                    Aquarias                 Rainbow six siege
# ..                        ...                               ...
# 519                       NaN                               NaN
# 520                       idk                       WOW classic
# 521                 Aquarius                            FIFA 20
# 522                 Aquarious                     Rocket League
# 523                     Libra                         Uncharted
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 1                              Basketball                        Rice
# 2                                    None                       Eggs
# 3                                   catan                  tteokbokki
# 4                                   Catan                       Tacos
# ..                                    ...                         ...
# 519                                   NaN                         NaN
# 520                             badminton                        rice
# 521                                 Chess                       Pizza
# 522                                 Poker                       Tacos
# 523                            Basketball             Eggs with bacon
#
#     What's your favorite movie?
# 0                             ?
# 1               The conjouring
# 2                       Flipped
# 3                   dune (2021)
# 4            End of Evangelion
# ..                          ...
# 519                         NaN
# 520        guardians of gahoole
# 521            Avengers Endgame
# 522                   Inception
# 523                Interstellar
#
# [524 rows x 120 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **in a text editor** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'Number 1 or Number 2?',
#  'Number 3 or Number 5?',
#  'What is your preferred way of saying one half?',
#  '7UP or Sierra Mist?',
#  'Android or iOS?',
#  'Apple or Orange?',
#  'Beef or Pork?',
#  'Your birthday is...',
#  'Do you prefer to wear black or white?',
#  'Boba or Coffee?',
#  'Cake or Pie?',
#  'Canes or Chick-fil-a?',
#  'Do you pour milk or cereal first?',
#  'Do you prefer chocolate or vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi?',
#  'Cookies or Ice Cream?',
#  'Do you prefer ice cream in a cup or in a cone?',
#  'Do you prefer dad or mom?',
#  'Marvel or DC?',
#  'Are you living in a dorm or an apartment?',
#  'Your last digit in your NetID...',
#  'Were you born in an even or odd month of the year?',
#  'Would you rather have the superpower of flight or invisibility?',
#  'UIUC Football or Basketball Team?',
#  'French Fries or Tater Tots?',
#  'Heads or Tails?',
#  'Hot Weather or Cold Weather?',
#  'Hot Dogs or Hamburgers?',
#  'In-State or Out-of-State/International',
#  'Introvert or Extrovert?',
#  'Do you consider yourself to have long or short hair?',
#  'Do you primarily use Windows or Mac?',
#  'You Identify As?',
#  'Morning Person or Night Person?',
#  'Favorite Root Beer Brand',
#  'Do you prefer the letter N or the letter M?',
#  'Does pineapple belong on pizza?',
#  'Is the day of the month your birthday falls on even or odd?',
#  'Is the year of your birthday even or odd?',
#  'Do you like partying at the University of Urbana-Champaign or do you want to go back home?',
#  'Do you prefer pens or pencils?',
#  'Pink or Blue',
#  'Pizza or Burger',
#  'Pizza or Sushi',
#  'What subject do you prefer?',
#  'Do you prefer rain or clear weather?',
#  'Pizza or Ramen',
#  'Rap Music or Pop Music?',
#  'Red or Blue?',
#  'Regular Cakes or Cupcakes?',
#  'Spring or Fall?',
#  'Starbucks or Dunkin?',
#  'Is your major STEM or non STEM?',
#  'Strawberry or Melon?',
#  'Summer or Winter?',
#  'Who would win: Superman or Homelander?',
#  'Which came first, the chicken or the egg?',
#  'The Office or Friends?',
#  'TV Shows or Movies?',
#  'Are you an upperclassmen or an underclassmen?',
#  'Pancakes or Waffles?',
#  'XBox or Playstation?',
#  'Do you have any pets?',
#  'Will you turn 19 before October?',
#  'Do you eat breakfast?',
#  'Do you like deep dish pizza?',
#  'Is this your first year at UIUC?',
#  'Do you drive a car?',
#  'Are you a dog person?',
#  'Is a hotdog a sandwich?',
#  'Do you use the busses?',
#  'Do you wear glasses?',
#  'Do you have a TV in your room?',
#  'Did you go to the Illinois vs Wyoming game last Saturday?',
#  'Are you taking RHET 105 this semester?',
#  'When did you wake up today?',
#  'Do you have a sibling?',
#  'Have you ever gotten COVID-19?',
#  'Do you bring a water bottle to class?',
#  'How many credit hours are you taking this semester?',
#  'Do you like school dorms?',
#  'How tall are you?',
#  'Do you play any sports?',
#  'Are your ears pierced?',
#  'Do you believe in life on other planets?',
#  'Do you have experience with computer programming before DISCOVERY?',
#  'Does your UIN end with an even number?',
#  'Study Strategy: Stay Up Late or Get Up Early?',
#  'Have you ever had a student loan?',
#  'Data Science DISCOVERY is',
#  'Do you fold up or ball toilet paper?',
#  'What day during the month is your birthday?',
#  'At what age do you think you will die?',
#  'From 1 to 10, how happy are you right now?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking this semester?.1',
#  'How many classes do you have on Friday?',
#  'How many countries have you been to outside the US?',
#  'How many hours of sleep did you get last night?',
#  'How many hours of sleep do you get on average?',
#  'How many meals do you have one day?',
#  'How many pets do you have?',
#  'How many roommates do you have?',
#  'How many siblings do you have?',
#  'How many years do you plan to study at university?',
#  'What is your favorite number?',
#  'What was your second choice for college (excluding your top choice of UIUC)?',
#  'What is your favorite coffee shop drink?',
#  'What is your favorite mobile app?',
#  'What is your favorite subject?',
#  'Who is your favorite singer?',
#  'What is your favorite season?',
#  'What is your Zodiac sign?',
#  'What is your favorite video game?',
#  'What is your favorite non-video game?',
#  'What is your favorite food?',
#  "What's your favorite movie?"]

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name in the variable `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = "Do you have any pets?"
analysis_column
# Out:
# 'Do you have any pets?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( analysis_column in df ), "Make certain your analysis_column is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you may want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the set for `df`, and the second set for the column name.
# - You can find this syntax under the "Subset Variables (Columns)" on your cheat sheet!
#
# Us Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#     Do you have any pets?
# 0                      No
# 1                      No
# 2                      No
# 3                      No
# 4                      No
# ..                    ...
# 519                    No
# 520                    No
# 521                   Yes
# 522                   Yes
# 523                    No
#
# [524 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "Yes"]
df1
# Out:
#              Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 6        Esbeida    AYA                    2.0                    5.0
# 7         Jocelyn   AYS                    1.0                    5.0
# 10        Maxwell   AYJ                    1.0                    5.0
# 11         Ashley   AYN                    2.0                    5.0
# 12          Aimee   AYM                    1.0                    3.0
# ..            ...   ...                    ...                    ...
# 514          Bill   AYA                    1.0                    3.0
# 517        Lauren   AYP                    1.0                    3.0
# 518       Celesta   AYS                    1.0                    3.0
# 521  Shivam Patel   AYC                    1.0                    3.0
# 522         Colin   AYI                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 6                                            2-Jan                 7UP
# 7                                            2-Jan         Sierra Mist
# 10                                           2-Jan                 7UP
# 11                                             0.5         Sierra Mist
# 12                                           2-Jan                 7UP
# ..                                             ...                 ...
# 514                                          2-Jan                 7UP
# 517                                          2-Jan                 7UP
# 518                                            0.5                 7UP
# 521                                            0.5                 7UP
# 522                                          2-Jan         Sierra Mist
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 6               iOS           Orange          Beef     On/After July 1  ...
# 7               iOS           Orange          Beef     On/After July 1  ...
# 10              iOS           Orange          Beef     On/After July 1  ...
# 11              iOS            Apple          Beef   On/Before June 30  ...
# 12              iOS            Apple          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 514             iOS           Orange          Beef   On/Before June 30  ...
# 517             iOS            Apple          Beef   On/Before June 30  ...
# 518             iOS            Apple          Beef     On/After July 1  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 522             iOS           Orange          Beef   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 6                       Iced vanilla coffee
# 7                Caramel crunch Frappuccino
# 10                  Peach green tea lemonade
# 11                         Caramel Macchiato
# 12                 Cold brew (Pumpkin cream)
# ..                                       ...
# 514                                 Starbuck
# 517                                      tea
# 518                              Frappuccino
# 521                          Don’t have one
# 522                                      tea
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 6                           Snapchat                            Math
# 7                             Spotify                        History
# 10                            Spotify                           Math
# 11                             Sudoku                           Math
# 12                            twitter                Social science
# ..                                ...                            ...
# 514                           Discord                           STAT
# 517                         instagram                        english
# 518                         instagram                        science
# 521                           Youtube                 World History
# 522                           YouTube                           Math
#
#     Who is your favorite singer? What is your favorite season?  \
# 6                     The Weeknd                          Fall
# 7                 Olivia rodrigo                        Winter
# 10                        Eminem                          Fall
# 11             Rex Orange County                          Fall
# 12                 Taylor swift                         Spring
# ..                           ...                           ...
# 514                 Taylor Swift                        Summer
# 517                ariana grande                        summer
# 518                          bts                        winter
# 521                   Kumar Sanu                        Summer
# 522                   The Weeknd                        Summer
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 6                  Capricorn                         Mario Kart
# 7                      Cancer         Link:  breath of the wild
# 10                    Scorpio                         Minecraft
# 11                     Cancer                    Stardew Valley
# 12                     Gemini                               GTA
# ..                        ...                               ...
# 514                    Taurus                         Minecraft
# 517                   taurus                       call of duty
# 518                 capricorn                        mario kart
# 521                 Aquarius                            FIFA 20
# 522                 Aquarious                     Rocket League
#
#     What is your favorite non-video game? What is your favorite food?  \
# 6                 Cards Against Humanity                        Pasta
# 7                           Secret Hitler         Chicken noodle soup
# 10                               Monopoly                        Poke
# 11                 Cards Against Humanity                        Soup
# 12                              Monopoly                        Tacos
# ..                                    ...                         ...
# 514                                   Uno                       Salad
# 517                          flappy bird                       pasta
# 518                        genshin impact                       ramen
# 521                                 Chess                       Pizza
# 522                                 Poker                       Tacos
#
#     What's your favorite movie?
# 6                        Wall-E
# 7             Top gun maverick
# 10                    Inception
# 11                  Parent Trap
# 12                       Grease
# ..                          ...
# 514                Interstellar
# 517               the notebook
# 518             disney rapanzel
# 521            Avengers Endgame
# 522                   Inception
#
# [223 rows x 120 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "No"]
df2
# Out:
#         Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0     CA Ana  AL1                    2.0                    5.0
# 1     CA Ram  AYR                    2.0                    5.0
# 2     CA Xin  AYO                    1.0                    5.0
# 3      Lekha  AYH                    2.0                    2.0
# 4       Reni  AYD                    2.0                    5.0
# ..       ...  ...                    ...                    ...
# 515   Faayez  AYT                    2.0                    5.0
# 516   Edward  AYQ                    1.0                    5.0
# 519     Bill  AYC                    1.0                    5.0
# 520  Renault  AYR                    2.0                    5.0
# 523     Evan  AYG                    2.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 1                                            2-Jan                 7UP
# 2                                            2-Jan         Sierra Mist
# 3                                              0.5                 7UP
# 4                                            2-Jan                 7UP
# ..                                             ...                 ...
# 515                                          2-Jan                 7UP
# 516                                            0.5         Sierra Mist
# 519                                          2-Jan         Sierra Mist
# 520                                            0.5         Sierra Mist
# 523                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 1               iOS            Apple           NaN     On/After July 1  ...
# 2               iOS            Apple          Beef   On/Before June 30  ...
# 3               iOS           Orange          Pork     On/After July 1  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 515         Android            Apple          Beef   On/Before June 30  ...
# 516             iOS           Orange          Beef     On/After July 1  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
# 520         Android           Orange          Pork   On/Before June 30  ...
# 523         Android           Orange          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 1                               Black coffee
# 2                                  starbucks
# 3                        pumpkin spice latte
# 4                                      Mocha
# ..                                       ...
# 515                               Chai latte
# 516                                    Philz
# 519                                      NaN
# 520                                     moca
# 523                                      Tea
#
#     What is your favorite mobile app?  What is your favorite subject?  \
# 0                            Snapchat                            Math
# 1                      Google chrome                      Mathematics
# 2                           Starbucks                      Psychology
# 3                             twitter               english (writing)
# 4                           Instagram                            Math
# ..                                ...                             ...
# 515                           Spotify                       Economics
# 516                       Xiaohongshu                         Finance
# 519                               NaN                             NaN
# 520                           wechat                              cs
# 523                          Facebook  Probability and Measure Theory
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 1                          TWICE                        Spring
# 2                  Five Exercuse                        Winter
# 3                   lana del rey                        autumn
# 4                  Mark kozelek                         Winter
# ..                           ...                           ...
# 515                  Arjit Singh                          Fall
# 516                   Bruno Mars                        summer
# 519                          NaN                           NaN
# 520              Michael Jackson                        Spring
# 523               Fredie Mercury                        Winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 1                     Scorpio      Player Unkown's Battleground
# 2                    aquarius                              None
# 3                         leo                   animal crossing
# 4                    Aquarias                 Rainbow six siege
# ..                        ...                               ...
# 515                    Pisces                           Fifa 22
# 516               Sagittarius                I don't play games
# 519                       NaN                               NaN
# 520                       idk                       WOW classic
# 523                     Libra                         Uncharted
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 1                              Basketball                        Rice
# 2                                    None                       Eggs
# 3                                   catan                  tteokbokki
# 4                                   Catan                       Tacos
# ..                                    ...                         ...
# 515                                Tennis                      Nihari
# 516                    I don't play games                    Barbecue
# 519                                   NaN                         NaN
# 520                             badminton                        rice
# 523                            Basketball             Eggs with bacon
#
#     What's your favorite movie?
# 0                             ?
# 1               The conjouring
# 2                       Flipped
# 3                   dune (2021)
# 4            End of Evangelion
# ..                          ...
# 515        Pursuit of Happiness
# 516        Persuit of Happiness
# 519                         NaN
# 520        guardians of gahoole
# 523                Interstellar
#
# [298 rows x 120 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# *Yes = 223/521 * 100 = 42.8% | 298/521 * 100 = 57.2%*

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# *I am surprised by the fact that the number of people who dont have pets is greater than the number of people that do. Based on my personal experience, I was expecting the opposite.*

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# *No I do not believe mine is the closest as the difference is greater than 5%*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#           Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 226      Jakub  AYD                    1.0                    5.0
# 173   Jonathan  AYR                    2.0                    3.0
# 330      Lalit  AYG                    1.0                    5.0
# 205    Baoyuan  AYF                    1.0                    5.0
# 160      Evan   AYD                    1.0                    5.0
# ..         ...  ...                    ...                    ...
# 345   baijiang  AYH                    1.0                    3.0
# 500        Ray  AYO                    2.0                    5.0
# 310  Changrong  AYL                    1.0                    5.0
# 132     Jenna   AYE                    2.0                    5.0
# 125    Michael  AYE                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 226                                          2-Jan                 7UP
# 173                                            0.5                 7UP
# 330                                          2-Jan                 7UP
# 205                                          2-Jan         Sierra Mist
# 160                                          2-Jan                 7UP
# ..                                             ...                 ...
# 345                                          2-Jan         Sierra Mist
# 500                                          2-Jan                 7UP
# 310                                          2-Jan         Sierra Mist
# 132                                          2-Jan         Sierra Mist
# 125                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 226             iOS            Apple          Beef   On/Before June 30  ...
# 173         Android            Apple          Beef     On/After July 1  ...
# 330             iOS            Apple          Pork   On/Before June 30  ...
# 205         Android           Orange          Beef     On/After July 1  ...
# 160             iOS           Orange          Beef     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 345         Android            Apple          Pork   On/Before June 30  ...
# 500         Android            Apple          Beef     On/After July 1  ...
# 310             iOS            Apple          Beef     On/After July 1  ...
# 132             iOS            Apple          Beef   On/Before June 30  ...
# 125             iOS            Apple          Beef   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 226                       Carmel Frappuccino
# 173                                Green Tea
# 330                           Caramel Frappe
# 205                           latte w/ cream
# 160                                    Latte
# ..                                       ...
# 345                                 milk tea
# 500                                    water
# 310                                Starbucks
# 132               Matcha latte with oat milk
# 125                        caramel macchiato
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 226                          Snapchat                         Coding
# 173                         Instagram                             CS
# 330                          Snapchat                      Economics
# 205                            wechat                           stat
# 160                           Twitter                       History
# ..                                ...                            ...
# 345                          appstore                         eco102
# 500                            Aidoku                       business
# 310                            wechat                     basketball
# 132                           Tik Tok                        English
# 125                            Safari                      Astronomy
#
#     Who is your favorite singer? What is your favorite season?  \
# 226                      J. Cole                        Spring
# 173                     Jay Chou                          Fall
# 330                 Travis Scott                        Summer
# 205                 taylor swift                        summer
# 160                 Frank Ocean                           Fall
# ..                           ...                           ...
# 345                          eve                        summer
# 500        Ikuta Lilas (YOASOBI)                        Winter
# 310                       Eminem                        Summer
# 132                  Jon Bellion                          Fall
# 125                    Yorushika                        Autumn
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 226                    Taurus      Star Wars Jedi: Fallen Order
# 173                       Leo                            Sudoku
# 330                   Taurus                              GTA 5
# 205                    virgos                          terraria
# 160                     Virgo                      Call of Duty
# ..                        ...                               ...
# 345                    monkey                              apex
# 500                    Cancer                     Rocket League
# 310                   Scorpio                              Apex
# 132                    Gemini                  Animal Crossing
# 125                    Taurus                     Hollow Knight
#
#     What is your favorite non-video game? What is your favorite food?  \
# 226                Cards Against Humanity                       Pizza
# 173                              Monopoly                       Sushi
# 330                                   Uno         Indian Shrimp Curry
# 205                      Unstable Unicorn                       steak
# 160                                  Life                   Spaghetti
# ..                                    ...                         ...
# 345                             badminton                       bread
# 500                                  golf                    Takoyaki
# 310                         I am the boss                    hot dogs
# 132                          Mantis Falls                Chicken Parm
# 125                                   UNO                       Ramen
#
#     What's your favorite movie?
# 226                       Borat
# 173    The theory of everything
# 330    The Pursuit of Happyness
# 205                     Ironman
# 160           Good Will Hunting
# ..                          ...
# 345                   your name
# 500               Kimi no na wa
# 310                  green book
# 132           Fantastic Mr. Fox
# 125                   Your Name
#
# [262 rows x 120 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#            Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 329      Alicia  AYJ                    2.0                    3.0
# 150       Ethan  AYI                    1.0                    5.0
# 407         KAI  AYA                    1.0                    3.0
# 429       Faith  AYC                    1.0                    3.0
# 349       Noam   AYM                    1.0                    3.0
# ..          ...  ...                    ...                    ...
# 67        Jamin  AYI                    2.0                    5.0
# 78   Jacqueline  AYQ                    2.0                    5.0
# 138        Sean  AYJ                    2.0                    3.0
# 92      Charlie  AYD                    1.0                    3.0
# 450      Andrew  AYA                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 329                                            0.5         Sierra Mist
# 150                                          2-Jan         Sierra Mist
# 407                                            0.5                 7UP
# 429                                          2-Jan                 7UP
# 349                                            0.5         Sierra Mist
# ..                                             ...                 ...
# 67                                             0.5         Sierra Mist
# 78                                           2-Jan                 7UP
# 138                                          2-Jan         Sierra Mist
# 92                                             0.5                 7UP
# 450                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 329             iOS            Apple          Pork   On/Before June 30  ...
# 150             iOS            Apple          Beef     On/After July 1  ...
# 407             iOS           Orange          Beef     On/After July 1  ...
# 429             iOS           Orange          Beef     On/After July 1  ...
# 349             iOS           Orange          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 67              iOS            Apple          Beef     On/After July 1  ...
# 78              iOS            Apple          Beef     On/After July 1  ...
# 138             iOS            Apple          Beef     On/After July 1  ...
# 92          Android           Orange          Beef     On/After July 1  ...
# 450             iOS            Apple          Beef     On/After July 1  ...
#
#     What is your favorite coffee shop drink?  \
# 329                            Caramel Latte
# 150                      Anything but coffee
# 407         Winter Melon tea wth gross jelly
# 429                             Matcha latte
# 349                            Hot Chocolate
# ..                                       ...
# 67                              Matcha latte
# 78                                 Starbucks
# 138                                   coffee
# 92                              I don't know
# 450                                Starbucks
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 329                         Instagram                        Science
# 150                          Snapchat                           Math
# 407                            WeChat                    Photography
# 429                         Instagram                           Math
# 349                         Instagram                       Not sure
# ..                                ...                            ...
# 67                            Youtube                        Science
# 78                     Subway Surfers                        History
# 138                           youtube                             cs
# 92                             Notion          Game study and design
# 450                           youtube               Computer Science
#
#     Who is your favorite singer? What is your favorite season?  \
# 329                          NCT                          Fall
# 150                     Cody Fry                        Summer
# 407                     Jay Chou                       Winter
# 429                 Taylor Swift                        Summer
# 349                   Bruno Mars                        Winter
# ..                           ...                           ...
# 67                    Nate Ruess                        Winter
# 78                 Morgan Wallen                        Summer
# 138                   jonas blue                        autumn
# 92                  Charlie Puth                        Autumn
# 450                   John Mayer                        winter
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 329                     Aries                 League of Legends
# 150                       Leo                     Rocket League
# 407               Sagittarius                           Pokemon
# 429                       Leo                    Star Wars Lego
# 349                 Capricorn                          Valorant
# ..                        ...                               ...
# 67                      libra                 League of Legends
# 78                      Libra                        Just Dance
# 138                    cancer                              apex
# 92                    Scorpio                          Rimworld
# 450                       leo                          valorant
#
#     What is your favorite non-video game? What is your favorite food?  \
# 329                              Monopoly        Korean fried chicken
# 150                                 Chess                    Stir Fry
# 407                              Billiard                         麻辣烫
# 429                   Splendor board game                       Sushi
# 349                                 Poker                  apple tart
# ..                                    ...                         ...
# 67                      Crossword puzzles                      Salmon
# 78                 Cards Against Humanity                   Ice Cream
# 138                                 poker               fried noodles
# 92                              Badminton              salmon sashimi
# 450                            basketball                      cheeze
#
#     What's your favorite movie?
# 329                Corpse Bride
# 150              A Silent Voice
# 407                   Initial D
# 429                  La La Land
# 349                   Inception
# ..                          ...
# 67         Howl's Moving Castle
# 78             The Longest Ride
# 138              now you see me
# 92     The Shawshank Redemption
# 450         Night at the Museum
#
# [262 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#           Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 14   Tianxiang  AYR                    1.0                    5.0
# 16     Claudia  AL1                    2.0                    3.0
# 25   Shreshika  AYB                    2.0                    3.0
# 26       Irith  AYI                    1.0                    3.0
# 29      Shriya  AYR                    NaN                    3.0
# ..         ...  ...                    ...                    ...
# 500        Ray  AYO                    2.0                    5.0
# 506    Stanley  AYL                    1.0                    3.0
# 508      Julio  AYC                    2.0                    5.0
# 518    Celesta  AYS                    1.0                    3.0
# 519       Bill  AYC                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 14                                           2-Jan                 7UP
# 16                                           2-Jan         Sierra Mist
# 25                                           2-Jan                 7UP
# 26                                           2-Jan                 7UP
# 29                                           2-Jan                 7UP
# ..                                             ...                 ...
# 500                                          2-Jan                 7UP
# 506                                          2-Jan                 7UP
# 508                                          2-Jan         Sierra Mist
# 518                                            0.5                 7UP
# 519                                          2-Jan         Sierra Mist
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 14          Android           Orange          Pork     On/After July 1  ...
# 16              iOS            Apple          Beef     On/After July 1  ...
# 25              iOS           Orange           NaN   On/Before June 30  ...
# 26          Android           Orange          Pork   On/Before June 30  ...
# 29              iOS            Apple           NaN     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 500         Android            Apple          Beef     On/After July 1  ...
# 506             iOS            Apple          Beef   On/Before June 30  ...
# 508             iOS           Orange          Pork     On/After July 1  ...
# 518             iOS            Apple          Beef     On/After July 1  ...
# 519             iOS            Apple          Beef     On/After July 1  ...
#
#               What is your favorite coffee shop drink?  \
# 14                                           Starbucks
# 16   Ice caramel macchiato or salted caramel cream ...
# 25                                                 NaN
# 26                                      Hot Chocolate
# 29                                         Iced Mochas
# ..                                                 ...
# 500                                              water
# 506                                             macha
# 508                                       Black coffee
# 518                                        Frappuccino
# 519                                                NaN
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 14                             Wechat                             CS
# 16                           Disney +                           Math
# 25                             Tiktok                     Chemistry
# 26                           YouTube                         History
# 29                          Instagram                           Math
# ..                                ...                            ...
# 500                            Aidoku                       business
# 506                           youtube                           math
# 508                         Instagram                        English
# 518                         instagram                        science
# 519                               NaN                            NaN
#
#     Who is your favorite singer? What is your favorite season?  \
# 14                          Gaga                        Spring
# 16                        Giveon                       Spring
# 25                           NaN                        Winter
# 26                 Lewis Capaldi                        Spring
# 29                       DPR Ian                          Fall
# ..                           ...                           ...
# 500        Ikuta Lilas (YOASOBI)                        Winter
# 506                      J. cole                        winter
# 508                 Layne Staley                          Fall
# 518                          bts                        winter
# 519                          NaN                           NaN
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 14                     Monkey                               LOL
# 16                 Capricorn                         Smash bros
# 25                    Gemini                                NaN
# 26                     Pisces                              Fifa
# 29                      Libra                         Minecraft
# ..                        ...                               ...
# 500                    Cancer                     Rocket League
# 506                    gemini                              apex
# 508                   Scorpio                            GTA IV
# 518                 capricorn                        mario kart
# 519                       NaN                               NaN
#
#     What is your favorite non-video game? What is your favorite food?  \
# 14                                   Ball                        Chip
# 16                                    Uno                     Chicken
# 25                                    NaN                       Pasta
# 26                       Soccer(Football)                     Burgers
# 29               ERS (Egyptian Rat Screw)                         Pho
# ..                                    ...                         ...
# 500                                  golf                    Takoyaki
# 506                               mahjong                       steak
# 508                              Monopoly                    Pad Thai
# 518                        genshin impact                       ramen
# 519                                   NaN                         NaN
#
#     What's your favorite movie?
# 14                   Star Wars
# 16                      Tangled
# 25                          NaN
# 26                   La la Land
# 29                     Coraline
# ..                          ...
# 500               Kimi no na wa
# 506                     yes man
# 508                  The Matrix
# 518             disney rapanzel
# 519                         NaN
#
# [128 rows x 120 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# *Our code would include both of them as we ran df.sample on the original dataset and not a dataset which excludes people who were already put into one group*

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index)]
control
# Out:
#          Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0      CA Ana   AL1                    2.0                    5.0
# 1      CA Ram   AYR                    2.0                    5.0
# 2      CA Xin   AYO                    1.0                    5.0
# 4        Reni   AYD                    2.0                    5.0
# 6    Esbeida    AYA                    2.0                    5.0
# ..        ...   ...                    ...                    ...
# 513       Jen   AYC                    2.0                    5.0
# 514      Bill   AYA                    1.0                    3.0
# 515    Faayez   AYT                    2.0                    5.0
# 516    Edward   AYQ                    1.0                    5.0
# 517    Lauren   AYP                    1.0                    3.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 1                                            2-Jan                 7UP
# 2                                            2-Jan         Sierra Mist
# 4                                            2-Jan                 7UP
# 6                                            2-Jan                 7UP
# ..                                             ...                 ...
# 513                                          2-Jan                 7UP
# 514                                          2-Jan                 7UP
# 515                                          2-Jan                 7UP
# 516                                            0.5         Sierra Mist
# 517                                          2-Jan                 7UP
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 1               iOS            Apple           NaN     On/After July 1  ...
# 2               iOS            Apple          Beef   On/Before June 30  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# 6               iOS           Orange          Beef     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 513         Android            Apple          Pork     On/After July 1  ...
# 514             iOS           Orange          Beef   On/Before June 30  ...
# 515         Android            Apple          Beef   On/Before June 30  ...
# 516             iOS           Orange          Beef     On/After July 1  ...
# 517             iOS            Apple          Beef   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 1                               Black coffee
# 2                                  starbucks
# 4                                      Mocha
# 6                       Iced vanilla coffee
# ..                                       ...
# 513                                     None
# 514                                 Starbuck
# 515                               Chai latte
# 516                                    Philz
# 517                                      tea
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 0                            Snapchat                           Math
# 1                      Google chrome                     Mathematics
# 2                           Starbucks                     Psychology
# 4                           Instagram                           Math
# 6                           Snapchat                            Math
# ..                                ...                            ...
# 513                           Twitter                           Art
# 514                           Discord                           STAT
# 515                           Spotify                      Economics
# 516                       Xiaohongshu                        Finance
# 517                         instagram                        english
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 1                          TWICE                        Spring
# 2                  Five Exercuse                        Winter
# 4                  Mark kozelek                         Winter
# 6                     The Weeknd                          Fall
# ..                           ...                           ...
# 513                         ABBA                        Winter
# 514                 Taylor Swift                        Summer
# 515                  Arjit Singh                          Fall
# 516                   Bruno Mars                        summer
# 517                ariana grande                        summer
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 1                     Scorpio      Player Unkown's Battleground
# 2                    aquarius                              None
# 4                    Aquarias                 Rainbow six siege
# 6                  Capricorn                         Mario Kart
# ..                        ...                               ...
# 513              Sagittarius                              Zelda
# 514                    Taurus                         Minecraft
# 515                    Pisces                           Fifa 22
# 516               Sagittarius                I don't play games
# 517                   taurus                       call of duty
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 1                              Basketball                        Rice
# 2                                    None                       Eggs
# 4                                   Catan                       Tacos
# 6                 Cards Against Humanity                        Pasta
# ..                                    ...                         ...
# 513                                  Uno          Bacon Cheeseburger
# 514                                   Uno                       Salad
# 515                                Tennis                      Nihari
# 516                    I don't play games                    Barbecue
# 517                          flappy bird                       pasta
#
#     What's your favorite movie?
# 0                             ?
# 1               The conjouring
# 2                       Flipped
# 4            End of Evangelion
# 6                        Wall-E
# ..                          ...
# 513           Schindler's List
# 514                Interstellar
# 515        Pursuit of Happiness
# 516        Persuit of Happiness
# 517               the notebook
#
# [262 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:
# ...feel free to add extra "Code" cells here if needed.
if treatment[treatment.Name == "Ammar"].empty:
    print("In control")
    display(control[control.Name == "Ammar"])
else:
    print("In treatment")
    display(treatment[treatment.Name == "Ammar"])
# Out:
# In treatment
#      Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 23  Ammar  AYB                    1.0                    5.0
#
#    What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 23                                            0.5                 7UP
#
#    Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 23             iOS           Orange          Beef   On/Before June 30  ...
#
#    What is your favorite coffee shop drink? What is your favorite mobile app?  \
# 23                              Frappuccino                          Facebook
#
#    What is your favorite subject? Who is your favorite singer?  \
# 23               Computer Science                       Weeknd
#
#    What is your favorite season? What is your Zodiac sign?  \
# 23                        Spring                    Cancer
#
#    What is your favorite video game? What is your favorite non-video game?  \
# 23                 Horizon Zero Dawn                                  Golf
#
#    What is your favorite food? What's your favorite movie?
# 23                       Pizza                       Seven
#
# [1 rows x 120 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# *Treatment*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking has us creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#           Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 313     Jaypal       AYT                    1.0                    5.0
# 353       Rick       AYM                    1.0                    5.0
# 201     Ashley       AYQ                    1.0                    5.0
# 71     Jihyeon       AYG                    1.0                    5.0
# 44      Kaylee       AYL                    2.0                    5.0
# ..         ...       ...                    ...                    ...
# 342       Will       AYM                    2.0                    5.0
# 517     Lauren       AYP                    1.0                    3.0
# 361     Maciej       AYB                    2.0                    5.0
# 312       Gaby       AYR                    1.0                    3.0
# 270  CA Alyssa  AYE, AYG                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 313                                            0.5                 7UP
# 353                                          2-Jan         Sierra Mist
# 201                                            0.5         Sierra Mist
# 71                                           2-Jan         Sierra Mist
# 44                                           2-Jan                 7UP
# ..                                             ...                 ...
# 342                                            0.5         Sierra Mist
# 517                                          2-Jan                 7UP
# 361                                          2-Jan                 7UP
# 312                                            0.5                 7UP
# 270                                          2-Jan         Sierra Mist
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 313             iOS            Apple          Pork   On/Before June 30  ...
# 353             iOS           Orange          Beef     On/After July 1  ...
# 201             iOS            Apple           NaN   On/Before June 30  ...
# 71              iOS           Orange          Beef     On/After July 1  ...
# 44              iOS           Orange          Pork     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 342             iOS            Apple          Pork   On/Before June 30  ...
# 517             iOS            Apple          Beef   On/Before June 30  ...
# 361             iOS            Apple          Beef   On/Before June 30  ...
# 312             iOS            Apple          Beef   On/Before June 30  ...
# 270             iOS            Apple          Pork     On/After July 1  ...
#
#              What is your favorite coffee shop drink?  \
# 313                                         Starbucks
# 353                                         Starbucks
# 201                                            coffee
# 71   Iced oatmilk latte with caramel swirls at Dunkin
# 44                                      Caramel latte
# ..                                                ...
# 342                                            Coffee
# 517                                               tea
# 361                                 Ice Vanilla Latte
# 312                                              Tea
# 270                                        oolong tea
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 313                           Netflix                       STAT 107
# 353                         Instagram                   Data science
# 201                         pinterest                            NaN
# 71                          Instagram            Business Analytics
# 44                            Discord              Political science
# ..                                ...                            ...
# 342                            Sudoku                           Math
# 517                         instagram                        english
# 361                          Snapchat                           Math
# 312                         snapchat                     Accounting
# 270                           twitter                     statistics
#
#     Who is your favorite singer? What is your favorite season?  \
# 313                One Direction                        Summer
# 353                Daniel Ceaser                        Winter
# 201                          NaN                        spring
# 71   Yeongji Lee (Korean Rapper)                          Fall
# 44                  Taylor Swift                        Spring
# ..                           ...                           ...
# 342                 Taylor Swift                          Fall
# 517                ariana grande                        summer
# 361                   The Weeknd                        Spring
# 312                          BTS                          Fall
# 270                       bladee                          fall
#
#     What is your Zodiac sign?  \
# 313                    gemini
# 353                       Leo
# 201                   gemini
# 71                      Virgo
# 44                      Virgo
# ..                        ...
# 342                    Taurus
# 517                   taurus
# 361                    Taurus
# 312                     Aries
# 270                     virgo
#
#                      What is your favorite video game?  \
# 313                                           Valorant
# 353                                           Valorant
# 201                                                NaN
# 71   I don't play video game (I don't know any vide...
# 44                                                SSBU
# ..                                                 ...
# 342                                            Foxhole
# 517                                       call of duty
# 361                          Call of Duty: Black Ops 3
# 312                                          Fall guys
# 270                                     stardew valley
#
#     What is your favorite non-video game?         What is your favorite food?  \
# 313                                Soccer                             Noodles
# 353                              Monopoly                       Chinese foods
# 201                                   NaN                     sweet potatoes
# 71                  I don't play any game                            Sukiyaki
# 44                            Minesweeper  Lotus seed and salted egg mooncake
# ..                                    ...                                 ...
# 342                                Sorry!                             Lobster
# 517                          flappy bird                               pasta
# 361                              Monopoly                               Pizza
# 312                           Board games                                Soup
# 270                              sequence                               sushi
#
#              What's your favorite movie?
# 313                                   83
# 353               Kung fu panda trilogy
# 201                         the titanic
# 71       The secret life of Walter Mitty
# 44   Beautiful Accident (Chinese: 美好的意外)
# ..                                   ...
# 342                           Caddyshack
# 517                        the notebook
# 361                     Django Unchained
# 312                         Forrest Gump
# 270                         finding nemo
#
# [112 rows x 120 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[~df1.index.isin(df1_treatment.index)]
df1_control
# Out:
#              Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 6        Esbeida    AYA                    2.0                    5.0
# 7         Jocelyn   AYS                    1.0                    5.0
# 11         Ashley   AYN                    2.0                    5.0
# 14      Tianxiang   AYR                    1.0                    5.0
# 17           Wing   AYB                    1.0                    5.0
# ..            ...   ...                    ...                    ...
# 512      Veronica   AYO                    1.0                    3.0
# 514          Bill   AYA                    1.0                    3.0
# 518       Celesta   AYS                    1.0                    3.0
# 521  Shivam Patel   AYC                    1.0                    3.0
# 522         Colin   AYI                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 6                                            2-Jan                 7UP
# 7                                            2-Jan         Sierra Mist
# 11                                             0.5         Sierra Mist
# 14                                           2-Jan                 7UP
# 17                                           2-Jan         Sierra Mist
# ..                                             ...                 ...
# 512                                          2-Jan                 7UP
# 514                                          2-Jan                 7UP
# 518                                            0.5                 7UP
# 521                                            0.5                 7UP
# 522                                          2-Jan         Sierra Mist
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 6               iOS           Orange          Beef     On/After July 1  ...
# 7               iOS           Orange          Beef     On/After July 1  ...
# 11              iOS            Apple          Beef   On/Before June 30  ...
# 14          Android           Orange          Pork     On/After July 1  ...
# 17              iOS            Apple          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 512             iOS            Apple          Beef   On/Before June 30  ...
# 514             iOS           Orange          Beef   On/Before June 30  ...
# 518             iOS            Apple          Beef     On/After July 1  ...
# 521             iOS            Apple           NaN   On/Before June 30  ...
# 522             iOS           Orange          Beef   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 6                       Iced vanilla coffee
# 7                Caramel crunch Frappuccino
# 11                         Caramel Macchiato
# 14                                 Starbucks
# 17                        Bridgeport Coffees
# ..                                       ...
# 512            Vanilla sweet cream cold brew
# 514                                 Starbuck
# 518                              Frappuccino
# 521                          Don’t have one
# 522                                      tea
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 6                           Snapchat                            Math
# 7                             Spotify                        History
# 11                             Sudoku                           Math
# 14                             Wechat                             CS
# 17                           iMessage                           Math
# ..                                ...                            ...
# 512                        Pokemon Go                        History
# 514                           Discord                           STAT
# 518                         instagram                        science
# 521                           Youtube                 World History
# 522                           YouTube                           Math
#
#     Who is your favorite singer? What is your favorite season?  \
# 6                     The Weeknd                          Fall
# 7                 Olivia rodrigo                        Winter
# 11             Rex Orange County                          Fall
# 14                          Gaga                        Spring
# 17                            IU                        Winter
# ..                           ...                           ...
# 512                      Wallows                          Fall
# 514                 Taylor Swift                        Summer
# 518                          bts                        winter
# 521                   Kumar Sanu                        Summer
# 522                   The Weeknd                        Summer
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 6                  Capricorn                         Mario Kart
# 7                      Cancer         Link:  breath of the wild
# 11                     Cancer                    Stardew Valley
# 14                     Monkey                               LOL
# 17                   Aquarius                          Valorant
# ..                        ...                               ...
# 512                 Capricorn                       Super Smash
# 514                    Taurus                         Minecraft
# 518                 capricorn                        mario kart
# 521                 Aquarius                            FIFA 20
# 522                 Aquarious                     Rocket League
#
#     What is your favorite non-video game? What is your favorite food?  \
# 6                 Cards Against Humanity                        Pasta
# 7                           Secret Hitler         Chicken noodle soup
# 11                 Cards Against Humanity                        Soup
# 14                                   Ball                        Chip
# 17                      Exploding Kittens                     Lobster
# ..                                    ...                         ...
# 512                              paranoia                       sushi
# 514                                   Uno                       Salad
# 518                        genshin impact                       ramen
# 521                                 Chess                       Pizza
# 522                                 Poker                       Tacos
#
#     What's your favorite movie?
# 6                        Wall-E
# 7             Top gun maverick
# 11                  Parent Trap
# 14                   Star Wars
# 17            Avengers End Game
# ..                          ...
# 512                Little Women
# 514                Interstellar
# 518             disney rapanzel
# 521            Avengers Endgame
# 522                   Inception
#
# [111 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#           Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 264     Christ       AYB                    1.0                    3.0
# 155      Grace       AYN                    1.0                    5.0
# 395     Rohit        AYR                    1.0                    5.0
# 160      Evan        AYD                    1.0                    5.0
# 120      Jerry       AYI                    1.0                    3.0
# ..         ...       ...                    ...                    ...
# 63        Abhi       AYE                    1.0                    3.0
# 18        Neil       AYL                    2.0                    5.0
# 235        Kei       AYE                    1.0                    5.0
# 211          K       AYG                    1.0                    5.0
# 110  ByeongJip  AYK, AYQ                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 264                                          2-Jan         Sierra Mist
# 155                                            0.5                 NaN
# 395                                          2-Jan                 7UP
# 160                                          2-Jan                 7UP
# 120                                          2-Jan                 7UP
# ..                                             ...                 ...
# 63                                           2-Jan                 7UP
# 18                                           2-Jan                 7UP
# 235                                            0.5         Sierra Mist
# 211                                          2-Jan                 7UP
# 110                                          2-Jan                 NaN
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 264             iOS            Apple          Beef   On/Before June 30  ...
# 155         Android           Orange          Pork   On/Before June 30  ...
# 395             iOS            Apple          Pork     On/After July 1  ...
# 160             iOS           Orange          Beef     On/After July 1  ...
# 120             iOS            Apple          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 63              iOS            Apple          Pork     On/After July 1  ...
# 18              iOS            Apple          Beef   On/Before June 30  ...
# 235             iOS           Orange          Beef   On/Before June 30  ...
# 211             iOS            Apple          Beef   On/Before June 30  ...
# 110             iOS           Orange          Pork     On/After July 1  ...
#
#      What is your favorite coffee shop drink?  \
# 264                                       NaN
# 155                    honey lemon ginger tea
# 395                             Caramel Mocha
# 160                                     Latte
# 120                                 starbucks
# ..                                        ...
# 63                         Don’t drink coffee
# 18   Iced Mocha Latte with 2 shots of caramel
# 235                                 Macchiato
# 211                                       NaN
# 110                                       NaN
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 264                         Instagram                           Math
# 155                            Google               Foreign Language
# 395                            Google                  Data Science
# 160                           Twitter                       History
# 120                            wechat                             cs
# ..                                ...                            ...
# 63                            Youtube                             CS
# 18                            Discord                     Statistics
# 235                            Google                           Math
# 211                               NaN                            NaN
# 110                            Google                      MATH STAT
#
#     Who is your favorite singer? What is your favorite season?  \
# 264                 Brent Faiyaz                          Fall
# 155                         AKMU                        Autumn
# 395                   Juice WRLD                          Fall
# 160                 Frank Ocean                           Fall
# 120                                                     autumn
# ..                           ...                           ...
# 63                  Chris Martin                          Fall
# 18                       Taeyeon                        Summer
# 235                  Mr.Children                          Fall
# 211                          NaN                          fall
# 110                          NaN                        Spring
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 264                     Aries                          Nba 2K22
# 155                     Aries                        Sly Cooper
# 395                     Libra                         Destiny 2
# 160                     Virgo                      Call of Duty
# 120                    monkey                         overwatch
# ..                        ...                               ...
# 63                      Virgo                League of legends
# 18                     Gemini                          VALORANT
# 235                     Aries                           Pokemon
# 211                       NaN                               NaN
# 110                     virgo                               NaN
#
#     What is your favorite non-video game? What is your favorite food?  \
# 264                                   Uno                     Chicken
# 155                                 Mafia                    tomatoes
# 395                              Monopoly              Orange Chicken
# 160                                  Life                   Spaghetti
# 120                                yugioh                     chicken
# ..                                    ...                         ...
# 63                             Volleyball                       Pizza
# 18                                 Sudoku              Butter Chicken
# 235                                 Jenga                       Sushi
# 211                                   NaN                      burger
# 110                                   NaN                       ramen
#
#     What's your favorite movie?
# 264                         Rio
# 155          Memories of Murder
# 395                     Pushpa
# 160           Good Will Hunting
# 120
# ..                          ...
# 63    The pursuit of happyness
# 18            Top Gun: Maverick
# 235                Forrest Gump
# 211                    War Dogs
# 110                         NaN
#
# [149 rows x 120 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[~df2.index.isin(df2_treatment.index)]
df2_control
# Out:
#         Name  Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 0     CA Ana  AL1                    2.0                    5.0
# 4       Reni  AYD                    2.0                    5.0
# 5     Linger  AYF                    2.0                    5.0
# 8    Suvinay  AYP                    1.0                    5.0
# 9     Advika  AYK                    1.0                    3.0
# ..       ...  ...                    ...                    ...
# 480     Yang  AYR                    1.0                    5.0
# 489  Xueying  AYT                    1.0                    3.0
# 495    Aiden  AL1                    2.0                    3.0
# 508    Julio  AYC                    2.0                    5.0
# 520  Renault  AYR                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 0                                            2-Jan         Sierra Mist
# 4                                            2-Jan                 7UP
# 5                                            2-Jan                 7UP
# 8                                            2-Jan                 7UP
# 9                                            2-Jan         Sierra Mist
# ..                                             ...                 ...
# 480                                            0.5         Sierra Mist
# 489                                          2-Jan                 7UP
# 495                                          2-Jan                 7UP
# 508                                          2-Jan         Sierra Mist
# 520                                            0.5         Sierra Mist
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 0               iOS            Apple          Pork   On/Before June 30  ...
# 4               iOS            Apple          Pork   On/Before June 30  ...
# 5               iOS            Apple          Beef   On/Before June 30  ...
# 8           Android           Orange           NaN     On/After July 1  ...
# 9               iOS           Orange          Pork     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 480             iOS            Apple          Beef     On/After July 1  ...
# 489         Android            Apple          Beef     On/After July 1  ...
# 495         Android            Apple          Beef   On/Before June 30  ...
# 508             iOS           Orange          Pork     On/After July 1  ...
# 520         Android           Orange          Pork   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 0                                  Cold brew
# 4                                      Mocha
# 5                                 Starbucks
# 8                                Frappuccino
# 9                         iced caramel latte
# ..                                       ...
# 480                            Vanilla Latte
# 489                                     none
# 495                                java chip
# 508                             Black coffee
# 520                                     moca
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 0                            Snapchat                           Math
# 4                           Instagram                           Math
# 5                          App Store                       Any STEM
# 8                             Netflix                      Astronomy
# 9                            snapchat                           math
# ..                                ...                            ...
# 480                            Phoneq                           Stat
# 489                            google                        physics
# 495                          snapchat                        stat107
# 508                         Instagram                        English
# 520                           wechat                             cs
#
#     Who is your favorite singer? What is your favorite season?  \
# 0                   Taylor Swift                          Fall
# 4                  Mark kozelek                         Winter
# 5                 Don’t have one                          Fall
# 8                Freddie Mercury                        Spring
# 9                     The Weeknd                          fall
# ..                           ...                           ...
# 480                   Seventeen                           Fall
# 489                 Zheng zhihua                        autumn
# 495                        Oasis                        winter
# 508                 Layne Staley                          Fall
# 520              Michael Jackson                        Spring
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 0                      Piceis                         Minecraft
# 4                    Aquarias                 Rainbow six siege
# 5                      Gemini                         Minecraft
# 8                 Sagitarrius                         Minecraft
# 9                sagittarius                         mario kart
# ..                        ...                               ...
# 480                       Leo                          Valorant
# 489                        ..                         Starcraft
# 495                    taurus                            league
# 508                   Scorpio                            GTA IV
# 520                       idk                       WOW classic
#
#     What is your favorite non-video game? What is your favorite food?  \
# 0                      Chutes and Ladders                      Yogurt
# 4                                   Catan                       Tacos
# 5                                     UNO      Authentic Chinese Food
# 8                                   Chess                Basmati Rice
# 9                          subway surfers      chocolate chip cookies
# ..                                    ...                         ...
# 480                                Mario?                     Pad Sew
# 489                          hearthstone?                        fish
# 495                              monopoly                  mac&cheese
# 508                              Monopoly                    Pad Thai
# 520                             badminton                        rice
#
#     What's your favorite movie?
# 0                             ?
# 4            End of Evangelion
# 5                  Harry Potter
# 8                  Interstellar
# 9                legally blonde
# ..                          ...
# 480                Harry Potter
# 489                      secret
# 495             Revenge of Sith
# 508                  The Matrix
# 520        guardians of gahoole
#
# [149 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`:

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#           Name       Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 313     Jaypal       AYT                    1.0                    5.0
# 353       Rick       AYM                    1.0                    5.0
# 201     Ashley       AYQ                    1.0                    5.0
# 71     Jihyeon       AYG                    1.0                    5.0
# 44      Kaylee       AYL                    2.0                    5.0
# ..         ...       ...                    ...                    ...
# 63        Abhi       AYE                    1.0                    3.0
# 18        Neil       AYL                    2.0                    5.0
# 235        Kei       AYE                    1.0                    5.0
# 211          K       AYG                    1.0                    5.0
# 110  ByeongJip  AYK, AYQ                    1.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 313                                            0.5                 7UP
# 353                                          2-Jan         Sierra Mist
# 201                                            0.5         Sierra Mist
# 71                                           2-Jan         Sierra Mist
# 44                                           2-Jan                 7UP
# ..                                             ...                 ...
# 63                                           2-Jan                 7UP
# 18                                           2-Jan                 7UP
# 235                                            0.5         Sierra Mist
# 211                                          2-Jan                 7UP
# 110                                          2-Jan                 NaN
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 313             iOS            Apple          Pork   On/Before June 30  ...
# 353             iOS           Orange          Beef     On/After July 1  ...
# 201             iOS            Apple           NaN   On/Before June 30  ...
# 71              iOS           Orange          Beef     On/After July 1  ...
# 44              iOS           Orange          Pork     On/After July 1  ...
# ..              ...              ...           ...                 ...  ...
# 63              iOS            Apple          Pork     On/After July 1  ...
# 18              iOS            Apple          Beef   On/Before June 30  ...
# 235             iOS           Orange          Beef   On/Before June 30  ...
# 211             iOS            Apple          Beef   On/Before June 30  ...
# 110             iOS           Orange          Pork     On/After July 1  ...
#
#              What is your favorite coffee shop drink?  \
# 313                                         Starbucks
# 353                                         Starbucks
# 201                                            coffee
# 71   Iced oatmilk latte with caramel swirls at Dunkin
# 44                                      Caramel latte
# ..                                                ...
# 63                                 Don’t drink coffee
# 18           Iced Mocha Latte with 2 shots of caramel
# 235                                         Macchiato
# 211                                               NaN
# 110                                               NaN
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 313                           Netflix                       STAT 107
# 353                         Instagram                   Data science
# 201                         pinterest                            NaN
# 71                          Instagram            Business Analytics
# 44                            Discord              Political science
# ..                                ...                            ...
# 63                            Youtube                             CS
# 18                            Discord                     Statistics
# 235                            Google                           Math
# 211                               NaN                            NaN
# 110                            Google                      MATH STAT
#
#     Who is your favorite singer? What is your favorite season?  \
# 313                One Direction                        Summer
# 353                Daniel Ceaser                        Winter
# 201                          NaN                        spring
# 71   Yeongji Lee (Korean Rapper)                          Fall
# 44                  Taylor Swift                        Spring
# ..                           ...                           ...
# 63                  Chris Martin                          Fall
# 18                       Taeyeon                        Summer
# 235                  Mr.Children                          Fall
# 211                          NaN                          fall
# 110                          NaN                        Spring
#
#     What is your Zodiac sign?  \
# 313                    gemini
# 353                       Leo
# 201                   gemini
# 71                      Virgo
# 44                      Virgo
# ..                        ...
# 63                      Virgo
# 18                     Gemini
# 235                     Aries
# 211                       NaN
# 110                     virgo
#
#                      What is your favorite video game?  \
# 313                                           Valorant
# 353                                           Valorant
# 201                                                NaN
# 71   I don't play video game (I don't know any vide...
# 44                                                SSBU
# ..                                                 ...
# 63                                  League of legends
# 18                                            VALORANT
# 235                                            Pokemon
# 211                                                NaN
# 110                                                NaN
#
#     What is your favorite non-video game?         What is your favorite food?  \
# 313                                Soccer                             Noodles
# 353                              Monopoly                       Chinese foods
# 201                                   NaN                     sweet potatoes
# 71                  I don't play any game                            Sukiyaki
# 44                            Minesweeper  Lotus seed and salted egg mooncake
# ..                                    ...                                 ...
# 63                             Volleyball                               Pizza
# 18                                 Sudoku                      Butter Chicken
# 235                                 Jenga                               Sushi
# 211                                   NaN                              burger
# 110                                   NaN                               ramen
#
#              What's your favorite movie?
# 313                                   83
# 353               Kung fu panda trilogy
# 201                         the titanic
# 71       The secret life of Walter Mitty
# 44   Beautiful Accident (Chinese: 美好的意外)
# ..                                   ...
# 63             The pursuit of happyness
# 18                     Top Gun: Maverick
# 235                         Forrest Gump
# 211                             War Dogs
# 110                                  NaN
#
# [261 rows x 120 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#           Name   Lab  Number 1 or Number 2?  Number 3 or Number 5?  \
# 6     Esbeida    AYA                    2.0                    5.0
# 7      Jocelyn   AYS                    1.0                    5.0
# 11      Ashley   AYN                    2.0                    5.0
# 14   Tianxiang   AYR                    1.0                    5.0
# 17        Wing   AYB                    1.0                    5.0
# ..         ...   ...                    ...                    ...
# 480       Yang   AYR                    1.0                    5.0
# 489    Xueying   AYT                    1.0                    3.0
# 495      Aiden   AL1                    2.0                    3.0
# 508      Julio   AYC                    2.0                    5.0
# 520    Renault   AYR                    2.0                    5.0
#
#     What is your preferred way of saying one half? 7UP or Sierra Mist?  \
# 6                                            2-Jan                 7UP
# 7                                            2-Jan         Sierra Mist
# 11                                             0.5         Sierra Mist
# 14                                           2-Jan                 7UP
# 17                                           2-Jan         Sierra Mist
# ..                                             ...                 ...
# 480                                            0.5         Sierra Mist
# 489                                          2-Jan                 7UP
# 495                                          2-Jan                 7UP
# 508                                          2-Jan         Sierra Mist
# 520                                            0.5         Sierra Mist
#
#     Android or iOS? Apple or Orange? Beef or Pork? Your birthday is...  ...  \
# 6               iOS           Orange          Beef     On/After July 1  ...
# 7               iOS           Orange          Beef     On/After July 1  ...
# 11              iOS            Apple          Beef   On/Before June 30  ...
# 14          Android           Orange          Pork     On/After July 1  ...
# 17              iOS            Apple          Beef   On/Before June 30  ...
# ..              ...              ...           ...                 ...  ...
# 480             iOS            Apple          Beef     On/After July 1  ...
# 489         Android            Apple          Beef     On/After July 1  ...
# 495         Android            Apple          Beef   On/Before June 30  ...
# 508             iOS           Orange          Pork     On/After July 1  ...
# 520         Android           Orange          Pork   On/Before June 30  ...
#
#     What is your favorite coffee shop drink?  \
# 6                       Iced vanilla coffee
# 7                Caramel crunch Frappuccino
# 11                         Caramel Macchiato
# 14                                 Starbucks
# 17                        Bridgeport Coffees
# ..                                       ...
# 480                            Vanilla Latte
# 489                                     none
# 495                                java chip
# 508                             Black coffee
# 520                                     moca
#
#     What is your favorite mobile app? What is your favorite subject?  \
# 6                           Snapchat                            Math
# 7                             Spotify                        History
# 11                             Sudoku                           Math
# 14                             Wechat                             CS
# 17                           iMessage                           Math
# ..                                ...                            ...
# 480                            Phoneq                           Stat
# 489                            google                        physics
# 495                          snapchat                        stat107
# 508                         Instagram                        English
# 520                           wechat                             cs
#
#     Who is your favorite singer? What is your favorite season?  \
# 6                     The Weeknd                          Fall
# 7                 Olivia rodrigo                        Winter
# 11             Rex Orange County                          Fall
# 14                          Gaga                        Spring
# 17                            IU                        Winter
# ..                           ...                           ...
# 480                   Seventeen                           Fall
# 489                 Zheng zhihua                        autumn
# 495                        Oasis                        winter
# 508                 Layne Staley                          Fall
# 520              Michael Jackson                        Spring
#
#     What is your Zodiac sign? What is your favorite video game?  \
# 6                  Capricorn                         Mario Kart
# 7                      Cancer         Link:  breath of the wild
# 11                     Cancer                    Stardew Valley
# 14                     Monkey                               LOL
# 17                   Aquarius                          Valorant
# ..                        ...                               ...
# 480                       Leo                          Valorant
# 489                        ..                         Starcraft
# 495                    taurus                            league
# 508                   Scorpio                            GTA IV
# 520                       idk                       WOW classic
#
#     What is your favorite non-video game? What is your favorite food?  \
# 6                 Cards Against Humanity                        Pasta
# 7                           Secret Hitler         Chicken noodle soup
# 11                 Cards Against Humanity                        Soup
# 14                                   Ball                        Chip
# 17                      Exploding Kittens                     Lobster
# ..                                    ...                         ...
# 480                                Mario?                     Pad Sew
# 489                          hearthstone?                        fish
# 495                              monopoly                  mac&cheese
# 508                              Monopoly                    Pad Thai
# 520                             badminton                        rice
#
#     What's your favorite movie?
# 6                        Wall-E
# 7             Top gun maverick
# 11                  Parent Trap
# 14                   Star Wars
# 17            Avengers End Game
# ..                          ...
# 480                Harry Potter
# 489                      secret
# 495             Revenge of Sith
# 508                  The Matrix
# 520        guardians of gahoole
#
# [260 rows x 120 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# *Blocking is when you divide the dataset into groups to block out certain variables so that they do not skew your final experiment for e.g. if you're comparing the results between students who did Praire Learn homework and students who did Handwritten and both groups had people who got As and Bs, you will block the students into groups of those who got As and those who got Bs and then subdivide them into control and treatment groups. This way your results don't get skewed by a variable. Blocking is usually done in small datasets as in large datasets the variable usually evens out.*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
